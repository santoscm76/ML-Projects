# %% [markdown]
# <a href="https://colab.research.google.com/github/santoscm76/ML-Projects/blob/master/Test_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style="darkgrid")

from google.colab import files
uploaded = files.upload()
import io
data = pd.read_csv(io.BytesIO(uploaded['petrol_consumption.csv']))
# Out:
#      <input type="file" id="files-cadb8472-05c2-47a6-9637-3e90f192e7aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cadb8472-05c2-47a6-9637-3e90f192e7aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving petrol_consumption.csv to petrol_consumption.csv

# %%
data.head()
# Out:
#    Petrol_tax  Average_income  ...  Population_Driver_licence(%)  Petrol_Consumption
# 0         9.0            3571  ...                         0.525                 541
# 1         9.0            4092  ...                         0.572                 524
# 2         9.0            3865  ...                         0.580                 561
# 3         7.5            4870  ...                         0.529                 414
# 4         8.0            4399  ...                         0.544                 410
#
# [5 rows x 5 columns]

# %%
X = data.iloc[:, 0:4].values
y = data.iloc[:, 4].values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
display_step = 100
from tensorflow.keras.layers import Input, Dense, Activation,Dropout
from tensorflow.keras.models import Model

input_layer = Input(shape=(X.shape[1],))
dense_layer_1 = Dense(100, activation='relu')(input_layer)
dense_layer_2 = Dense(50, activation='relu')(dense_layer_1)
dense_layer_3 = Dense(25, activation='relu')(dense_layer_2)
output = Dense(1)(dense_layer_3)

model = Model(inputs=input_layer, outputs=output)
model.compile(loss="mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])

history = model.fit(X_train, y_train, batch_size=2, epochs=2000, verbose=1, validation_split=0.2)

from sklearn.metrics import mean_squared_error
from math import sqrt

pred_train = model.predict(X_train)

if epoch % display_step == 0:
  print(np.sqrt(mean_squared_error(y_train,pred_train)))

pred = model.predict(X_test)

if epoch % display_step == 0:
  print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Epoch 1/2000
# 15/15 [==============================] - 1s 15ms/step - loss: 345678.8145 - mean_squared_error: 345678.8145 - val_loss: 402231.0938 - val_mean_squared_error: 402231.0938
# Epoch 2/2000
# 15/15 [==============================] - 0s 5ms/step - loss: 308239.2031 - mean_squared_error: 308239.2031 - val_loss: 401502.8750 - val_mean_squared_error: 401502.8750
# Epoch 3/2000
# 15/15 [==============================] - 0s 6ms/step - loss: 332401.9043 - mean_squared_error: 332401.9043 - val_loss: 400192.2500 - val_mean_squared_error: 400192.2500
# Epoch 4/2000
# 15/15 [==============================] - 0s 5ms/step - loss: 325219.2969 - mean_squared_error: 325219.2969 - val_loss: 397815.7500 - val_mean_squared_error: 397815.7500
# Epoch 5/2000
# 15/15 [==============================] - 0s 6ms/step - loss: 365641.3242 - mean_squared_error: 365641.3242 - val_loss: 393383.7500 - val_mean_squared_error: 393383.7500
# Epoch 6/2000
# ...
